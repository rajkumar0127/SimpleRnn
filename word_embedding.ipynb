# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent=['the glass of milk',
      'the glass of juice',
      'the cup of tea',
      'I am a good developer',
      'understand the meaning of words',
      'your videos are good']

# %%
voc_size=10000

# %%
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[836, 5594, 4886, 6043],
#  [836, 5594, 4886, 6392],
#  [836, 1076, 4886, 7987],
#  [6814, 3999, 8599, 311, 135],
#  [6302, 836, 3017, 4886, 5808],
#  [6592, 7595, 3168, 311]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_len=8
embeded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_len)
embeded_docs
# Out:
# array([[   0,    0,    0,    0,  836, 5594, 4886, 6043],
#        [   0,    0,    0,    0,  836, 5594, 4886, 6392],
#        [   0,    0,    0,    0,  836, 1076, 4886, 7987],
#        [   0,    0,    0, 6814, 3999, 8599,  311,  135],
#        [   0,    0,    0, 6302,  836, 3017, 4886, 5808],
#        [   0,    0,    0,    0, 6592, 7595, 3168,  311]])

# %%
#Feture Representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_len))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embeded_docs)
# Out:
# 1/1 [==============================] - 0s 461ms/step
# array([[[-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.02813144, -0.03135653, -0.03954162, -0.00081309,
#          -0.0244868 ,  0.04234565,  0.04453452,  0.03370715,
#          -0.01769393,  0.04783274],
#         [ 0.01306197,  0.04937451, -0.03494205, -0.00486966,
#          -0.04311557,  0.02298203, -0.01467167,  0.03199532,
#          -0.03391725,  0.03571818],
#         [ 0.00828578,  0.02990404, -0.00332619,  0.0079807 ,
#           0.02276584, -0.04298594,  0.00036643,  0.00702548,
#          -0.00943333,  0.00052264],
#         [ 0.02322086,  0.03928092,  0.03064238, -0.03499252,
#          -0.00337859,  0.03478033, -0.02566059,  0.02821015,
#          -0.0255031 , -0.02665011]],
#
#        [[-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.02813144, -0.03135653, -0.03954162, -0.00081309,
#          -0.0244868 ,  0.04234565,  0.04453452,  0.03370715,
#          -0.01769393,  0.04783274],
#         [ 0.01306197,  0.04937451, -0.03494205, -0.00486966,
#          -0.04311557,  0.02298203, -0.01467167,  0.03199532,
#          -0.03391725,  0.03571818],
#         [ 0.00828578,  0.02990404, -0.00332619,  0.0079807 ,
#           0.02276584, -0.04298594,  0.00036643,  0.00702548,
#          -0.00943333,  0.00052264],
#         [-0.00272671,  0.01992716, -0.0439579 , -0.00307336,
#           0.03632059,  0.04463036, -0.00420292, -0.01368445,
#          -0.00181172,  0.03555901]],
#
#        [[-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.02813144, -0.03135653, -0.03954162, -0.00081309,
#          -0.0244868 ,  0.04234565,  0.04453452,  0.03370715,
#          -0.01769393,  0.04783274],
#         [ 0.03767444,  0.00409025, -0.02344153,  0.0048877 ,
#          -0.02369747,  0.01057228, -0.04138828,  0.01101004,
#           0.02907837, -0.00993552],
#         [ 0.00828578,  0.02990404, -0.00332619,  0.0079807 ,
#           0.02276584, -0.04298594,  0.00036643,  0.00702548,
#          -0.00943333,  0.00052264],
#         [ 0.04656006,  0.04746911, -0.03488115, -0.01496061,
#           0.04641745, -0.0371955 ,  0.01826761, -0.04128002,
#           0.04102161,  0.00157022]],
#
#        [[-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.02727939, -0.00242992, -0.03387348, -0.0377124 ,
#          -0.01776748, -0.04980328,  0.03910631,  0.03071881,
#           0.0015443 , -0.02843953],
#         [ 0.0401935 , -0.04009505, -0.00355887, -0.01487275,
#          -0.02186196, -0.00853194, -0.02841908, -0.01286964,
#          -0.01318998, -0.00248724],
#         [-0.00538499,  0.00860996,  0.0181557 , -0.01592485,
#          -0.02168212, -0.0144604 , -0.01468868,  0.01367526,
#          -0.02484016,  0.03863971],
#         [-0.01831591, -0.03637177,  0.01612486, -0.0497289 ,
#           0.03630519,  0.01839444,  0.03628126, -0.04917929,
#           0.02859944,  0.01209799],
#         [ 0.01217934, -0.03344617,  0.03265542, -0.01689721,
#           0.04989915,  0.02451732, -0.02043189, -0.02607563,
#          -0.0322394 ,  0.03165117]],
#
#        [[-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.04229431, -0.00808394,  0.03979286, -0.04053663,
#           0.03377012, -0.00549481,  0.0072163 , -0.00309942,
#          -0.00527563,  0.01247115],
#         [-0.02813144, -0.03135653, -0.03954162, -0.00081309,
#          -0.0244868 ,  0.04234565,  0.04453452,  0.03370715,
#          -0.01769393,  0.04783274],
#         [-0.0064353 , -0.04580609, -0.0215254 , -0.01298059,
#          -0.04472796, -0.00045373, -0.01782324, -0.02376374,
#          -0.04692833,  0.04563055],
#         [ 0.00828578,  0.02990404, -0.00332619,  0.0079807 ,
#           0.02276584, -0.04298594,  0.00036643,  0.00702548,
#          -0.00943333,  0.00052264],
#         [-0.04752458,  0.0315835 , -0.01419966, -0.01638938,
#           0.04526392,  0.0021802 , -0.03706368, -0.0272884 ,
#           0.02444819,  0.00473226]],
#
#        [[-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.00385051, -0.0271233 , -0.03110415,  0.0159981 ,
#           0.01085085,  0.02648694, -0.04993545, -0.00283228,
#           0.02196861,  0.00279589],
#         [-0.04073931,  0.00250342,  0.03121804,  0.00965478,
#           0.0464483 , -0.02622862,  0.04885856, -0.04095143,
#          -0.01360229,  0.03009811],
#         [ 0.02924849, -0.02154299, -0.02984251, -0.00295   ,
#           0.00943429, -0.04301578, -0.04177276, -0.04753839,
#           0.04349217,  0.01431558],
#         [ 0.04532676, -0.01300298,  0.04066325,  0.0082375 ,
#           0.03218902,  0.01996268, -0.04371773, -0.01115332,
#          -0.04611797, -0.04678638],
#         [-0.01831591, -0.03637177,  0.01612486, -0.0497289 ,
#           0.03630519,  0.01839444,  0.03628126, -0.04917929,
#           0.02859944,  0.01209799]]], dtype=float32)
